# %% [markdown]
# # Neural Network SciPy tutorial
#
# Using a [Beginning Tutoral](https://www.springboard.com/blog/beginners-guide-neural-network-in-python-scikit-learn-0-18/), set up a simple neural network using scipy. This really just to get a neural network up and running.

# %%
import pandas as pd
wine = pd.read_csv('wine_data/wine.data', names=[
    "Cultivator", "Alchol", "Malic_Acid", "Ash", "Alcalinity_of_Ash", "Magnesium", 
    "Total_phenols", "Falvanoids", "Nonflavanoid_phenols", "Proanthocyanins", "Color_intensity", 
    "Hue", "OD280", "Proline"
])

# %%
wine.head()
# Out:
#    Cultivator  Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  \
# 0           1   14.23        1.71  2.43               15.6        127
# 1           1   13.20        1.78  2.14               11.2        100
# 2           1   13.16        2.36  2.67               18.6        101
# 3           1   14.37        1.95  2.50               16.8        113
# 4           1   13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Falvanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280  Proline
# 0             5.64  1.04   3.92     1065
# 1             4.38  1.05   3.40     1050
# ...

# %%
wine.describe().transpose()
# Out:
#                       count        mean         std     min       25%  \
# Cultivator            178.0    1.938202    0.775035    1.00    1.0000
# Alchol                178.0   13.000618    0.811827   11.03   12.3625
# Malic_Acid            178.0    2.336348    1.117146    0.74    1.6025
# Ash                   178.0    2.366517    0.274344    1.36    2.2100
# Alcalinity_of_Ash     178.0   19.494944    3.339564   10.60   17.2000
# Magnesium             178.0   99.741573   14.282484   70.00   88.0000
# Total_phenols         178.0    2.295112    0.625851    0.98    1.7425
# Falvanoids            178.0    2.029270    0.998859    0.34    1.2050
# Nonflavanoid_phenols  178.0    0.361854    0.124453    0.13    0.2700
# Proanthocyanins       178.0    1.590899    0.572359    0.41    1.2500
# Color_intensity       178.0    5.058090    2.318286    1.28    3.2200
# Hue                   178.0    0.957449    0.228572    0.48    0.7825
# ...

# %%
wine.shape
X = wine.drop('Cultivator',axis=1)
y = wine['Cultivator']

X
# Out:
#      Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  Total_phenols  \
# 0     14.23        1.71  2.43               15.6        127           2.80
# 1     13.20        1.78  2.14               11.2        100           2.65
# 2     13.16        2.36  2.67               18.6        101           2.80
# 3     14.37        1.95  2.50               16.8        113           3.85
# 4     13.24        2.59  2.87               21.0        118           2.80
# 5     14.20        1.76  2.45               15.2        112           3.27
# 6     14.39        1.87  2.45               14.6         96           2.50
# 7     14.06        2.15  2.61               17.6        121           2.60
# 8     14.83        1.64  2.17               14.0         97           2.80
# 9     13.86        1.35  2.27               16.0         98           2.98
# 10    14.10        2.16  2.30               18.0        105           2.95
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train.head()
# Out:
#     Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  Total_phenols  \
# 92   12.69        1.53  2.26               20.7         80           1.38
# 35   13.48        1.81  2.41               20.5        100           2.70
# 63   12.37        1.13  2.16               19.0         87           3.50
# 56   14.22        1.70  2.30               16.3        118           3.20
# 66   13.11        1.01  1.70               15.0         78           2.98
#
#     Falvanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 92        1.46                  0.58             1.62             3.05  0.96
# 35        2.98                  0.26             1.86             5.10  1.04
# 63        3.10                  0.19             1.87             4.45  1.22
# 56        3.00                  0.26             2.03             6.38  0.94
# 66        3.18                  0.26             2.28             5.30  1.12
#
#     OD280  Proline
# 92   2.06      495
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
type(scaler)
# Out:
# sklearn.preprocessing.data.StandardScaler

# %%
# Fit only to the training data
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
pd.DataFrame(X_train)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.445783 -0.749357 -0.495020  0.287034 -1.445746 -1.374306 -0.539482
# 1    0.530424 -0.505124  0.095276  0.223882  0.065922  0.695997  0.969605
# 2   -0.841208 -1.098261 -0.888551 -0.249760 -0.916662  1.950726  1.088743
# 3    1.444845 -0.601073 -0.337608 -1.102317  1.426424  1.480203  0.989461
# 4    0.073213 -1.202932 -2.698793 -1.512807 -1.596913  1.135153  1.168169
# 5   -0.000929 -0.574905 -1.360788 -2.333788 -0.538745  0.727366  1.257523
# 6   -0.742351  0.559034  1.000397  2.276333 -0.160828 -0.558732 -1.413164
# 7   -0.408711 -0.505124 -0.731139 -0.312913 -0.992246 -0.088208  0.522836
# 8   -1.730915 -0.627240  0.921691  1.960571 -0.841079 -0.527364 -0.390559
# 9   -1.038920 -1.045925 -2.502027 -0.944436  3.920678 -0.637152 -0.718190
# 10   0.814636  2.844355  0.252688  0.223882 -0.311995 -0.903782 -1.383379
# 11   0.567495 -0.513847  1.039750 -0.249760  0.821757  0.147053  0.522836
# ...

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=5000,verbose=True)
mlp.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 1.32503718
# Iteration 2, loss = 1.31049861
# Iteration 3, loss = 1.29609062
# Iteration 4, loss = 1.28187278
# Iteration 5, loss = 1.26774988
# Iteration 6, loss = 1.25386341
# Iteration 7, loss = 1.24011098
# Iteration 8, loss = 1.22641065
# Iteration 9, loss = 1.21279813
# Iteration 10, loss = 1.19921968
# Iteration 11, loss = 1.18569940
# Iteration 12, loss = 1.17220502
# Iteration 13, loss = 1.15879221
# Iteration 14, loss = 1.14547807
# Iteration 15, loss = 1.13223304
# Iteration 16, loss = 1.11899725
# Iteration 17, loss = 1.10578626
# Iteration 18, loss = 1.09260390
# Iteration 19, loss = 1.07938581
# Iteration 20, loss = 1.06617855
# Iteration 21, loss = 1.05305177
# Iteration 22, loss = 1.03995593
# Iteration 23, loss = 1.02693895
# Iteration 24, loss = 1.01395505
# Iteration 25, loss = 1.00100616
# Iteration 26, loss = 0.98810741
# Iteration 27, loss = 0.97526936
# Iteration 28, loss = 0.96243903
# Iteration 29, loss = 0.94961905
# ...

# %%
predictions = mlp.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(y_test,predictions)
# Out:
# array([[15,  0,  0],
#        [ 2, 19,  0],
#        [ 0,  1,  8]])
